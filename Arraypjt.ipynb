# %%
class pessoa:
  nome=str
  idade=int
  ocupacao=str

for pessoas in range(2):
  pessoa.nome=str(input("digite seu nome: "))
  pessoa.idade=input("digite sua Idade: ")
  pessoa.ocupacao=input("Qual sua Ocupação? :")
  print(f"Nome: {pessoa.nome}")
  print(f"idade: {pessoa.idade}")
  print(f"ocupacao: {pessoa.ocupacao}")
# Out:
# digite seu nome: G
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-c49c965de91e> in <module>
#       7
#       8 for pessoas in range(2):
# ----> 9   pessoa.nome=str(input("digite seu nome: "))
#      10   pessoa.idade=input("digite sua Idade: ")
#      11   pessoa.ocupacao=input("Qual sua Ocupação? :")
#
# AttributeError: 'dict' object has no attribute 'nome'

# %%
for i in range(10):
  print("oi")
# Out:
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
