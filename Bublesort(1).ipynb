# %%
lista=[5,3,1,2,4]
troca=True
while troca:
  for i in range(4):
    a=lista[i]
    b=lista[i+1]
    if(b<a):
      lista[i]=b
      lista[i+1]=a
      troca=True
      print(lista)
# Out:
# [3, 5, 1, 2, 4]
# [3, 1, 5, 2, 4]
# [3, 1, 2, 5, 4]
# [3, 1, 2, 4, 5]
# [1, 3, 2, 4, 5]
# [1, 2, 3, 4, 5]
