# %%
from pickle import APPEND
lista=[10,5,15,25,30]
while True:
  
  busca=int(input("Digite qual numero deseja buscar"))

  for n in range(len(lista)):
    if lista[n]==busca:
      i=n
      break
  if i>-1:
    print(f"{busca} encontrado em: {i}, portanto CADASTRADO")
    
  else:
    print("Numero nao encontrado, portanto NAO CADASTRADO")
    x=input("\nDigite um numero:")
    teste=lista.append(x)
    print(lista)
# Out:
# 10 encontrado em: 0, portanto CADASTRADO

# %%
lista=[10,15,33,25,37]

busca=int(input("Entre com numero"))
for n in range (len(lista)): 
  if lista[n]==busca:
    print("Numero encontrado na lista")
    print(lista[n])
    break
  else:
    print("Numero nao encontrado")
    break
# Out:
# Entre com numero55
# Numero nao encontrado
