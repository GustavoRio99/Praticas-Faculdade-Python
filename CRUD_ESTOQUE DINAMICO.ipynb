# %%
import os
import curses
class Estoque:
  itens={}
  
  def incluir(self, cod, desc, prec,qtd):
    if cod not in self.itens:
      self.itens[cod]={"Produto": desc, "Preço": prec}
      soma=int(self.itens[cod]["Preço"]) 
      total=soma*qtd
      print(total)
      lista=[total]
      print(lista)
    else:
      print("=============================")
      print("CODIGO de produto JÁ cadastrado.")
      print("=============================")
  def incluir_P(self, cod, qtd):
      resultado=float(self.itens[cod]*self.qtd)
      print(Resultado)
  def excluir(self, cod):
    if cod in self.itens:
      self.itens.pop(cod)
      print("=============================")
      print("Produto: EXCLUIDO pelo CODIGO")
      print("=============================")
    else:
      print("==================================")
      print("Produto NAO ENCONTRADO pelo CODIGO")
      print("==================================")
  def excluir_all(self):
      input("Pressione ENTER para continuar com a EXCULSAO")
      self.itens.clear()
      print("=============================")
      print("TODOS ITENS EXCLUIDO !!")
      print("=============================")
  def alterar(self,cod, prec):
    if cod in self.itens:
      self.itens[cod]["Preço"]=prec
    else:
      print("======================")
      print("produto NAO CADASTRADO")
      print("======================")
  def listar(self):
    
    for item in self.itens:
      print(item,self.itens[item]["Produto"], self.itens[item]["Preço"])
      
class Pedido:
  def __init__(self,n,c):
    self.numero=n
    self.cliente=c
    self.total=0
    self.itens=[] 
  def incluir(self,c,d,q,p):
    self.itens.append([c,d,q,p])
    self.total+=(q*p)
ext=int(0)
while ext!=1:
  print(" ======MENU==[PRINCIPAL]=======")
  print("|1 - ESTOQUE                    |")
  print("|2 - PEDIDO                     |")
  print("|3 - SAIR                       |")
  opc1=int(input("Escolha uma Opção:      "))
  print("|==============================")
  os.system('cls')
  if opc1 == 1:
    volta=True
    while volta:
      print(" ======MENU==[ESTOQUE]=======")
      print("|1 - Incluir                   |")
      print("|2 - Excluir TUDO              |")
      print("|3 - Excluir Produto Expecifico|")
      print("|4 - LISTAR                    |")
      print("|5 - VOLTAR                    |")
      opc2=int(input("Escolha uma Opção:     "))
      print("|==============================")
      os.system("cls")
      if opc2 == 1: 
        obj=Estoque()
        a=input("Codigo Produto: ")
        b=input("Descrição Produto: ")
        c=int(input("Preço: R$"))
        d=int(input("qtd"))
        obj.incluir(a, b, c,d)
        
        input("PRODUCO CADASTRADO COM SUCESSO...PRESS ENTER.")
        

      elif opc2 == 2:
        print("================EXCLUIR=ESTOQUE===============")
        input("|DESEJA EXCLUIR TODOS OS PRODUTOS DO ESTOQUE ?|")
        print("=============PRESS ENTER CONTINUAR.===========")
        obj.excluir_all()
      elif opc2 == 3:
        print("|=========EXCLUIR POR ID=========|")
        codigo=input("Codigo Produto: ")
        print("|================================|")
        input("PRODUTO EXCLUIDO COM SUCESSO...PRESS CONTINUAR", obj.itens[codigo])
        obj.excluir(codigo)
      elif opc2 == 4:
        obj=Estoque()
        print("=========================================================")
        print("Possui: ",len(obj.itens)," Produto(s) no estoque")
        obj.listar()
        print("=========================================================")
      elif opc2 == 5: 

        os.system('clear')
        volta=False
  elif opc1 == 2:
    volta=True
    while volta:
      print("+======MENU==[PEDIDO]==========+")
      print("|1 - Incluir                   |")
      print("|2 - Excluir TUDO              |")
      print("|3 - Excluir Produto Expecifico|")
      print("|4 - LISTAR                    |")
      print("|5 - VOLTAR                    |")
      opc2=int(input("Escolha uma Opção:     "))
      print("+==============================+")
      if opc2 == 1: 
        obj=Estoque()
        a=input("Codigo Produto: ")
        b=input("Descrição Produto: ")
        c=input("Preço: R$")
        input("PRODUCO CADASTRADO COM SUCESSO...PRESS ENTER.")
        obj.incluir(a, b, c)
      if opc2 == 5:
        volta=False
  elif opc1 == 3:
    print("=======================")
    print("Até Logo              |")   
    print("=======================")    
    break
# Out:
#  ======MENU==[PRINCIPAL]=======
# |1 - ESTOQUE                    |
# |2 - PEDIDO                     |
# |3 - SAIR                       |
# Escolha uma Opção:      2
# |==============================
# +======MENU==[PEDIDO]==========+
# |1 - Incluir                   |
# |2 - Excluir TUDO              |
# |3 - Excluir Produto Expecifico|
# |4 - LISTAR                    |
# |5 - VOLTAR                    |
# Escolha uma Opção:     1
# +==============================+
# Codigo Produto: 01
# Descrição Produto: 01x
# Preço: R$500
# PRODUCO CADASTRADO COM SUCESSO...PRESS ENTER.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-251c45ec2e95> in <module>
#     126         c=input("Preço: R$")
#     127         input("PRODUCO CADASTRADO COM SUCESSO...PRESS ENTER.")
# --> 128         obj.incluir(a, b, c)
#     129       if opc2 == 5:
#     130         volta=False
#
# ...

# %%
class Estoque:
  itens={}
  def incluir(self, c,d,p):
    if c not in self.itens:
      self.itens.update({c:[d,p]})
    else: 
      print("Produto Ja incluido")
  def excluir(self, c):
    self.itens.pop(c)
  def descricao(self, c):
    return self.itens[c][0]
  def preco(self,c):
    return self.itens[c][1]
  def listar(self):
    for c in self.itens:
      print(c,self.descricao(c),self.preco(c))
    
class Pedido:
  
  def __init__(self,n,c):
    self.numero=n
    self.cliente=c
    self.total=0
    self.
  def incluir(self q,p)
