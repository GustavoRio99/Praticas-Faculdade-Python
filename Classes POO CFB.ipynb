# %%
class Carro:
  velmax=0
  ligado=False
  cor=""
  def __init__(self, v,l,c):
    self.velmax=v
    self.ligado=l
    self.cor=c
  def mostrar(self):
    print(f"Velocidade Max:{self.velmax} ")
    estado= "sim" if self.ligado else "Nao"
    print(f"Ligado:{estado} ")
    print(f"Cor:{self.cor} ")
  def ligar(self):
    self.ligado = True
  def desligar(self):
    self.ligado = False
  def andar(self):
    if self.ligado:
      print("Ligado e Andando")
    else:
      print("Desligado, Ligue o carro.")

c1=Carro(200, False, "vermelho")
c2=Carro(100, False, "Amarelo")
c3=Carro(130, False, "Preto")
c1.ligar()
c1.mostrar() 
c1.desligar()
c1.mostrar()
# Out:
# Velocidade Max:200
# Ligado:sim
# Cor:vermelho
# Velocidade Max:200
# Ligado:Nao
# Cor:vermelho

# %%
class Retangulo:
  def __init__(self, pComprimento, pLargura):
    self.comprimento=pComprimento
    self.largura=pLargura
  def area(self):
    area=self.comprimento*self.largura
    print(area)
a=int(input("Entre com 1º numero: "))
b=int(input("Entre com 2º numero: "))
calc=Retangulo(a,b)
calc.area()
# Out:
# Entre com 1º numero: 10
# Entre com 2º numero: 10
# 100
