# %%
cod=0
produto={"1": {"Produto": "Batata Rufles Cebolinha R$", "Preço" : 7.99},
         "2": {"Produto": "Coca-cola Lata R$", "Preço" : 3.62},
         "3": {"Produto": "Big Apple R$", "Preço" : 39.90}}
while(cod!="0"):
  cod=(input("Entre com o codigo produto o digite 0 para SAIR: "))
  if(cod=="0"):
    print("Até logo...")
  elif cod in produto:
    print(produto[cod]["Produto"], produto[cod]["Preço"])
  else:
    print("Codigo nao encontrado")
# Out:
# Entre com o codigo produto o digite 0 para SAIR: 1
# Batata Rufles Cebolinha R$ 7.99
# Entre com o codigo produto o digite 0 para SAIR: 2
# Coca-cola Lata R$ 3.62
# Entre com o codigo produto o digite 0 para SAIR: 3
# Big Apple R$ 39.9
# Entre com o codigo produto o digite 0 para SAIR: 2
# Coca-cola Lata R$ 3.62
# Entre com o codigo produto o digite 0 para SAIR: 1
# Batata Rufles Cebolinha R$ 7.99
# Entre com o codigo produto o digite 0 para SAIR: 0
# Até logo...
