# %%
n=int(input("Informe a quantidade de numeros que deseja Multiplicar para achar o produto"))
acu2=int(0)

for i in range(n):
  a=int(input(f"digite o primeiro numero"))
  b=int(input(f"digite o segundo numero"))
  res=int(a*b)
acu2+=int(res)
print(f"O resultado do produto :{acu2}")
# Out:
# Informe a quantidade de numeros que deseja obter o produto2
# digite o primeiro numero2
# digite o segundo numero8
# digite o primeiro numero8
# digite o segundo numero8
# O resultado do produto :64
