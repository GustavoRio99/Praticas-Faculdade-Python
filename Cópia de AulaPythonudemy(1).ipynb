# %%
print("---------------------------------------")
cpf1=str(input("|Digite seu CPF: "))
nome1=str(input("|Digite seu Nome: ")) 
codp1=int(input("|Digite Codigo Produto: "))
prod1=str(input("|Produto: "))
qtd1=int(input("|Quantidade: "))
val1=str(input("|valor: "))
print("---------------------------------------")
# Out:
# ---------------------------------------
# |Digite seu CPF: 130.233.323.33
# |Digite seu Nome: Gustavo
# |Digite Codigo Produto: 001
# |Produto: Peira Gala 1 kg
# |Quantidade: 4
# |valor: 8.99
# ---------------------------------------

# %%
print("--------------PEDIDO------------------")
print(f"|Cpf: {cpf1}")
print(f"|nome: {nome1}")
print(f"|Codigo: {codp1}")
print(f"|Nome Produto: {prod1}")
print(f"|Quantidade: {qtd1}")
print(f"|Valor: {val1}")
print("---------------------------------------")
# Out:
# --------------PEDIDO------------------
# |Cpf: 130.233.323.33
# |nome: Gustavo
# |Codigo: 1
# |Nome Produto: Peira Gala 1 kg
# |Quantidade: 4
# |Valor: 8.99
# ---------------------------------------
