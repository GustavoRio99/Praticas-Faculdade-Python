# %%
print("-----------PEDIDO nº1----------------")
cpf1=str(input("|Digite seu CPF: "))
nome1=str(input("|Digite seu Nome: ")) 
codp1=int(input("|Digite Codigo Produto: "))
prod1=str(input("|Produto: "))
qtd1=int(input("|Quantidade: "))
val1=float(input("|valor: "))
print("---------------------------------------")
# Out:
# -----------PEDIDO nº1----------------
# |Digite seu CPF: 14020903732
# |Digite seu Nome: Gustavo Rio
# |Digite Codigo Produto: 1
# |Produto: Arroz 1kg
# |Quantidade: 2
# |valor: 10
# ---------------------------------------

# %%
print("-----------PRODUTO nº2----------------")

codp2=int(input("|Digite Codigo Produto: "))
prod2=str(input("|Produto: "))
qtd2=int(input("|Quantidade: "))
val2=float(input("|valor: "))
print("---------------------------------------")
# Out:
# -----------PRODUTO nº2----------------
# |Digite Codigo Produto: 2
# |Produto: feijao 2kg
# |Quantidade: 1
# |valor: 10
# ---------------------------------------

# %%
print("-----------PRODUTO nº3----------------")
codp3=int(input("|Digite Codigo Produto: "))
prod3=str(input("|Produto: "))
qtd3=int(input("|Quantidade: "))
val3=float(input("|valor: "))
print("---------------------------------------")
# Out:
# -----------PRODUTO nº3----------------
# |Digite Codigo Produto: 3
# |Produto: macarrao 1kg
# |Quantidade: 1
# |valor: 10
# ---------------------------------------

# %%
print("--------------PRODUTO nº1------------------")
print(f"|Cpf: {cpf1}")
print(f"|Codigo: {codp1}")
print(f"|Nome Produto: {prod1}")
print(f"|Quantidade: {qtd1}")
print(f"|Valor: {val1}")
print("---------------------------------------")
# Out:
# --------------PRODUTO nº1------------------
# |Cpf: 14020903744
# |Codigo: 1
# |Nome Produto: arroz 1kg
# |Quantidade: 1
# |Valor: 10.0
# ---------------------------------------

# %%
print("--------------PRODUTO nº2------------------")
print(f"|Codigo: {codp2}")
print(f"|Nome Produto: {prod2}")
print(f"|Quantidade: {qtd2}")
print(f"|Valor: {val2}")
print("---------------------------------------")
# Out:
# --------------PRODUTO nº2------------------
# |Codigo: 2
# |Nome Produto: feijao 2kg
# |Quantidade: 1
# |Valor: 10.0
# ---------------------------------------

# %%
print("--------------PRODUTO nº3------------------")
print(f"|Codigo: {codp3}")
print(f"|Nome Produto: {prod3}")
print(f"|Quantidade: {qtd3}")
print(f"|Valor: {val3}")
print("---------------------------------------")
# Out:
# --------------PRODUTO nº3------------------
# |Codigo: 3
# |Nome Produto: macarrao 1kg
# |Quantidade: 1
# |Valor: 10.0
# ---------------------------------------

# %%
res=float((val1*qtd1)+(val2*qtd2)+(val3*qtd3))

print("---------------------------------------")
print(f"Nome: {nome1}                         ")
print(f"CPF PEDIDO: {cpf1}                    ")
print(f"TOTAL PEDIDO: {res}                   ")
print("---------------------------------------")
# Out:
# ---------------------------------------
# Nome: Gustavo Rio
# CPF PEDIDO: 14020903732
# TOTAL PEDIDO: 40.0
# ---------------------------------------
