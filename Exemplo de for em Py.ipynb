# %%
notas=[10,4,6,8,7,3,5]
media=int(sum(notas)/len(notas))
aprovados=0
reprovados=0
for nota in notas:
  print(nota)
  if nota > 5:
    aprovados+=1
  else:
    reprovados+=1
    
print(f"Aprovados: {aprovados}")
print(f"Reprovado: {reprovados}")
print(f"Media: {media}")
# Out:
# 10
# 4
# 6
# 8
# 7
# 3
# 5
# Aprovados: 4
# Reprovado: 3
# Media: 6
