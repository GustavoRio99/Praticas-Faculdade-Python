# %%
def extenso(d,m,a,c):
  mes={1:"janeiro", 2:"fevereiro", 3:"marco", 4:"abril", 5:"maio", 6:"junho",
       7:"julho", 8:"agosto", 9:"setembro", 10:"outubro", 11:"novembro", 12:"dezembro"}
  dt= c+", "+str(d)+" de "+mes[m]+" de "+str(a)
  
  return dt

dt_ext=extenso(14,3,1992,"Rio de Janeiro")
print(dt_ext)
# Out:
# Rio de Janeiro, 14 de marco de 1992
