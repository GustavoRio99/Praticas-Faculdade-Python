# %%
class Aluno:
    def __init__(self, nome, idade, nota):
      self.n=nome
      self.i=idade
      self.no=nota
    def calcular(self):
      return sum(self.no/ len(self.no))

aluno1=Aluno("Gustavo", 31, [10,9,8])
aluno2=Aluno("luana", 32,[8,7,6])

aluno1.n.int(calcular())
