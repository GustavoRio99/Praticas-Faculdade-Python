# %%
lista=[1,1,2,10,3,3]
#Tenta usar o If lista in len(lista): 1, 0, 2, 10, 3, 0
def duplicidade(a):
  for n in a:
    if a[0]==a[1]:
      del a[1]
      a.insert(1,0)
    if a[0]==a[2]:
      del a[2]
      a.insert(2,0)
    if a[0]==a[3]:
      del a[3]
      a.insert(3,0)
    if a[0]==a[4]:
      del a[4]
      a.insert(4,0)
    if a[0]==a[5]:
      del a[5]
      a.insert(5,0)
    if a[1]==a[2]:
      del a[2]
      a.insert(2,0)
    if a[1]==a[3]:
      del a[3]
      a.insert(3,0)
    if a[1]==a[4]:
      del a[4]
      a.insert(4,0)
    if a[1]==a[5]:
      del a[5]
      a.insert(5,0)
    if a[2]==a[3]:
      del a[3]
      a.insert(3,0)
    if a[2]==a[4]:
      del a[4]
      a.insert(4,0)
    if a[2]==a[5]:
      del a[5]
      a.insert(5,0)
    if a[3]==a[4]:
      del a[4]
      a.insert(4,0)
    if a[3]==a[5]:
      del a[5]
      a.insert(5,0)
    if a[4]==a[5]:
      del a[5]
      a.insert(5,0)
  print(a)
duplicidade(lista)
# Out:
# [1, 0, 2, 10, 3, 0]

# %%
lista=[1,1,2,10,3,3]
set(lista)
# Out:
# {1, 2, 3, 10}
