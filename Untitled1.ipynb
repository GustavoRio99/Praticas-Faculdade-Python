# %%
raio=float(input("Informe o Raio do circulo: "))
area=float(3.14*raio**2)
print(f"Area do circulo: {area}")
# Out:
# Informe o Raio do circulo: 15
# Area do circulo: 706.5

# %%
a=10
b=3

print("a+b=", a+b)
print("a-b=", a-b)
print("a*b=", a*b)
print("a//b=", a//b)
print("a/b=", a/b)
print("a**b=", a**b)
# Out:
# a+b= 13
# a-b= 7
# a*b= 30
# a//b= 3
# a/b= 3.3333333333333335
# a**b= 1000

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-a467ea7d2d14> in <module>
# ----> 1 a+=str(a)
#       2 print(a)
#
# TypeError: unsupported operand type(s) for +=: 'int' and 'str'
