# %%
import random
x = random.randint(1,5)
n = int(input("Qual o numero? "))

if n==x:
  print(f"você ACERTOU, numero escolhido pelo Computador:")
else:
  print("você ERROU tente novamente")
# Out:
# Qual o numero? 3
# você ERROU tente novamente

# %%
import random
 
X = random.randint(1,5)
rodada = 1
 
print("O computador pensou em um numero de 1 a 5. Tente adivinhar")
 
while rodada <= 3:
  print("Esta a tentativa", rodada," de 3")
  N = int(input("Qual o numero? "))
  
  if N == X:
    print("Correto, voce venceu o jogo!")
    break
  else:
    print("Incorreto!")
    
  rodada+=1
 
if rodada>3:
  print("Sinto muito, mas o computador venceu o jogo!")
  print("O numero que o computador pensou foi",X)
# Out:
# O computador pensou em um numero de 1 a 5. Tente adivinhar
# Esta a tentativa 1  de 3
# Qual o numero? 2
# Incorreto!
# Esta a tentativa 2  de 3
# Qual o numero? 3
# Incorreto!
# Esta a tentativa 3  de 3
# Qual o numero? 4
# Incorreto!
# Sinto muito, mas o computador venceu o jogo!
# O numero que o computador pensou foi 5
